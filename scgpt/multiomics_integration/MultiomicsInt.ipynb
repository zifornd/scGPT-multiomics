# %%
import psutil
import GPUtil
import time

def check_system_usage():
    # Start time
    start_time = time.time()

    # CPU usage
    cpu_usage = psutil.cpu_percent()

    # Memory usage
    memory_info = psutil.virtual_memory()
    memory_usage = memory_info.percent

    # GPU usage
    gpus = GPUtil.getGPUs()
    gpu_info = [(gpu.id, gpu.name, gpu.load*100, gpu.memoryUsed, gpu.memoryTotal) for gpu in gpus]

    # End time
    end_time = time.time()
    execution_time = end_time - start_time

    # Print results
    print(f"CPU usage: {cpu_usage}%")
    print(f"Memory usage: {memory_usage}%")
    for gpu in gpu_info:
        print(f"GPU {gpu[0]}: {gpu[1]}, {gpu[2]}% load, {gpu[3]}MB used of {gpu[4]}MB")
    print(f"Execution time: {execution_time} seconds")

# %%
import copy
import gc
import json
import os
from pathlib import Path
import sys
import time
import traceback
#from typing import List, Tuple, Dict, Union, Optional
import warnings

import torch
from anndata import AnnData
import scanpy as sc
import scvi
import numpy as np
import wandb
from scipy.sparse import issparse
import matplotlib.pyplot as plt
from torch import nn
from torch.nn import functional as F
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from torchtext.vocab import Vocab
from torchtext._torchtext import (
    Vocab as VocabPybind,
)
import pandas as pd
import scipy.sparse as sp
from sklearn import preprocessing

sys.path.insert(0, "../")
from scgpt import prepare_data, prepare_dataloader, define_wandb_metrcis, evaluate, eval_testdata, train
from scgpt.tokenizer import tokenize_and_pad_batch
from scgpt.model import MultiOmicTransformerModel

import scgpt as scg
from scgpt.tokenizer.gene_tokenizer import GeneVocab
from scgpt.tokenizer import random_mask_value
from scgpt.loss import (
    masked_mse_loss,
    masked_relative_error,
    criterion_neg_log_bernoulli,
)
from scgpt.preprocess import Preprocessor
from scgpt.utils import set_seed, category_str2int, eval_scib_metrics

sc.set_figure_params(figsize=(4, 4))
os.environ["KMP_WARNINGS"] = "off"
warnings.filterwarnings('ignore')
# Out:
# Non-A100 GPU detected, using math or mem efficient attention if input tensor is on cuda
# torch.Size([32, 512])
# torch.Size([16, 256])
# torch.Size([64, 128])

# %%
hyperparameter_defaults = dict(
    task = 'multiomic',
    seed=42,
    dataset_name="BMMC", # Dataset name
    do_train=True, # Flag to indicate whether to do update model parameters during training
    load_model="./save/scGPT_human", # Path to pre-trained model
    freeze = False, #freeze
    GEP=True, # Gene expression modelling
    GEPC=True, # Gene expression modelling for cell objective
    CLS=False,
    ESC=False,
    DAR = True, # DAR objective weight for batch correction
    DSBN = False,  # Domain-spec batchnorm,
    mask_ratio=0.4, # Default mask ratio
    explicit_zero_prob = False,  # whether explicit bernoulli for zeros
    ecs_thres=0,  # Elastic cell similarity objective, 0.0 to 1.0, 0.0 to disable
    dab_weight=1.0,
    use_batch_labels = True,
    use_mod = True,
    per_seq_batch_sample = False,
    epochs= 25,   # Default number of epochs for fine-tuning
    input_layer_key = "X_binned", # Default expression value binning in data pre-processing
    n_bins= 51,    # Default number of bins for value binning in data pre-processing
    n_hvg = 1200,  # Default number of highly variable genes
    n_hvp = 4000,
    max_seq_len = 4001, # # Default n_hvg+1
    lr=1e-3, # Default learning rate for fine-tuning
    batch_size= 16, # Default batch size for fine-tuning
    layer_size=512,
    nlayers=4,
    nhead=8, # if load model, batch_size, layer_size, nlayers, nhead will be ignored
    dropout=0.2, # Default dropout rate during model fine-tuning
    schedule_ratio=0.95,  # Default rate for learning rate decay
    save_eval_interval=5, # Default model evaluation interval
    log_interval=100,  # Default log interval
    fast_transformer=True, # Default setting
    pre_norm=False, # Default setting
    amp=True,  # Default setting: Automatic Mixed Precision
    pad_token = "<pad>",
    mask_value = -1,
    pad_value = -2,
    include_zero_gene = False,
)

# %%
# Manually set the configuration
config = hyperparameter_defaults
print(config)
# Out:
# {'task': 'multiomic', 'seed': 42, 'dataset_name': 'BMMC', 'do_train': True, 'load_model': './save/scGPT_human', 'freeze': False, 'GEP': True, 'GEPC': True, 'CLS': False, 'ESC': False, 'DAR': True, 'DSBN': False, 'mask_ratio': 0.4, 'explicit_zero_prob': False, 'ecs_thres': 0, 'dab_weight': 1.0, 'use_batch_labels': True, 'use_mod': True, 'per_seq_batch_sample': False, 'epochs': 25, 'input_layer_key': 'X_binned', 'n_bins': 51, 'n_hvg': 1200, 'n_hvp': 4000, 'max_seq_len': 4001, 'lr': 0.001, 'batch_size': 16, 'layer_size': 512, 'nlayers': 4, 'nhead': 8, 'dropout': 0.2, 'schedule_ratio': 0.95, 'save_eval_interval': 5, 'log_interval': 100, 'fast_transformer': True, 'pre_norm': False, 'amp': True, 'pad_token': '<pad>', 'mask_value': -1, 'pad_value': -2, 'include_zero_gene': False}

# %%
def set_seed(seed):
    import random
    import numpy as np
    import torch

    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
        
#config = hyperparameter_defaults
# Set the seed using the value from the config
set_seed(config['seed'])

# %%
# Settings for input and preprocessing
special_tokens = [config['pad_token'], "<cls>", "<eoc>"]

# %%
dataset_name = config['dataset_name']
save_dir = Path(f"./save/dev_{dataset_name}-{time.strftime('%b%d-%H-%M')}/")
save_dir.mkdir(parents=True, exist_ok=True)
print(f"save to {save_dir}")
# Out:
# save to save/dev_BMMC-Nov20-05-05

# %%
logger = scg.logger
scg.utils.add_file_handler(logger, save_dir / "run.log")

# %%
import gzip
import shutil

# Path to the .gz file
input_gz_file = './data/BMMC_processed.h5ad.gz'
# Path to the output file
output_file = './data/BMMC_processed.h5ad'

# Open the .gz file and the output file
with gzip.open(input_gz_file, 'rb') as file_in:
    with open(output_file, 'wb') as file_out:
        # Copy the contents from the .gz file to the output file
        shutil.copyfileobj(file_in, file_out)

print(f"{output_file} has been created.")
# Out:
# ./data/BMMC_processed.h5ad has been created.

# %%
#Load the BMMC data ( COMMENT OUT IF USING THE ABOVE BLOCK)
if dataset_name == 'BMMC':
    adata = sc.read('./data/BMMC_processed.h5ad')
    # subset to first 3 donors with B, Mono and T cell subtypes
    adata = adata[adata.obs.DonorID.isin([10886, 11466, 12710]) & adata.obs.cell_type.isin(np.unique(adata.obs.cell_type.values)[:17])]
    adata.obs["celltype"] = adata.obs["cell_type"].astype(str).astype('category')
    adata.var["gene_name"] = adata.var.index.tolist()
    le = preprocessing.LabelEncoder()
    encoded_batch = le.fit_transform(adata.obs['batch'].values)
    adata.obs["batch_id"] =  encoded_batch
    adata.obs["str_batch"] = adata.obs["batch_id"].astype('category')
    adata_protein = adata[:, adata.var.feature_types.isin(['ADT'])].copy()
    adata_protein.var.index = ['p_' + i for i in adata_protein.var.index]
    adata = adata[:, adata.var.feature_types.isin(['GEX'])].copy()
    data_is_raw = False

check_system_usage()
# Out:
# CPU usage: 5.5%
# Memory usage: 7.6%
# GPU 0: NVIDIA A10G, 0.0% load, 4.0MB used of 23028.0MB
# Execution time: 0.033892154693603516 seconds

# %%
if config['use_mod']:
    gene_rna_df = pd.DataFrame(index = adata.var.index.tolist())
    gene_rna_df['mod'] = 'RNA'
    gene_protein_df = pd.DataFrame(index = adata_protein.var.index.tolist())
    gene_protein_df['mod'] = 'Protein'
    gene_loc_df = pd.concat([gene_rna_df, gene_protein_df])
    gene_loc_df['mod'] = gene_loc_df['mod'].astype('category')

# %%
display((gene_loc_df['mod']))
# Out:
# AL627309.5        RNA
# LINC01409         RNA
# LINC01128         RNA
# LINC00115         RNA
# FAM41C            RNA
#                ...
# p_HLA-E       Protein
# p_CD82        Protein
# p_CD101       Protein
# p_CD88        Protein
# p_CD224       Protein
# Name: mod, Length: 14087, dtype: category
# Categories (2, object): ['Protein', 'RNA']

# %%
#Cross-check gene set with the pre-trained model 
if config['load_model'] is not None:
    model_dir = Path(config['load_model'])
    model_config_file = model_dir / "args.json"
    model_file = model_dir / "best_model.pt"
    vocab_file = model_dir / "vocab.json"

    vocab = GeneVocab.from_file(vocab_file)
    for s in special_tokens:
        if s not in vocab:
            vocab.append_token(s)

    adata.var["id_in_vocab"] = [
        1 if gene in vocab else -1 for gene in adata.var["gene_name"]
    ]
    gene_ids_in_vocab = np.array(adata.var["id_in_vocab"])
    logger.info(
        f"match {np.sum(gene_ids_in_vocab >= 0)}/{len(gene_ids_in_vocab)} genes "
        f"in vocabulary of size {len(vocab)}."
    )
    old_vocab = vocab

# Set model parameters
embsize = config['layer_size']
nhead = config['nhead']
nlayers = config['nlayers']
d_hid = config['layer_size']

# Print the configuration to verify
print(f"Embedding size: {embsize}, Number of heads: {nhead}, Number of layers: {nlayers}, Hidden size: {d_hid}")
# Out:
# scGPT - INFO - match 12587/13953 genes in vocabulary of size 60697.
# Embedding size: 512, Number of heads: 8, Number of layers: 4, Hidden size: 512

# %%
preprocessor = Preprocessor(
    use_key="X",  # the key in adata.layers to use as raw data
    filter_gene_by_counts=1,  # step 1
    filter_cell_by_counts=1,  # step 2
    normalize_total=1e4,  # 3. whether to normalize the raw data and to what sum
    result_normed_key="X_normed",  # the key in adata.layers to store the normalized data
    log1p=data_is_raw,  # 4. whether to log1p the normalized data
    result_log1p_key="X_log1p",
    subset_hvg=config['n_hvg'],  # 5. whether to subset the raw data to highly variable genes
    hvg_flavor="seurat_v3" if data_is_raw else "cell_ranger",
    binning=config['n_bins'],  # 6. whether to bin the raw data and to what number of bins
    result_binned_key="X_binned",  # the key in adata.layers to store the binned data
)
preprocessor(adata, batch_key=None)

check_system_usage()
# Out:
# scGPT - INFO - Filtering genes by counts ...
# scGPT - INFO - Filtering cells by counts ...
# scGPT - INFO - Normalizing total counts ...
# scGPT - INFO - Subsetting highly variable genes ...
# scGPT - WARNING - No batch_key is provided, will use all cells for HVG selection.
# scGPT - INFO - Binning data ...
# CPU usage: 4.0%
# Memory usage: 7.4%
# GPU 0: NVIDIA A10G, 0.0% load, 4.0MB used of 23028.0MB
# Execution time: 0.0300443172454834 seconds

# %%
preprocessor_protein = Preprocessor(
    use_key="X",  # the key in adata.layers to use as raw data
    filter_gene_by_counts=0,  # step 1
    filter_cell_by_counts=False,  # step 2
    normalize_total=False,  # 3. whether to normalize the raw data and to what sum
    result_normed_key="X_normed",  # the key in adata.layers to store the normalized data
    log1p=False,  # 4. whether to log1p the normalized data
    result_log1p_key="X_log1p",
    subset_hvg=False,  # 5. whether to subset the raw data to highly variable genes
    hvg_flavor=None,
    binning=config['n_bins'],  # 6. whether to bin the raw data and to what number of bins
    result_binned_key="X_binned",  # the key in adata.layers to store the binned data
)
preprocessor_protein(adata_protein, batch_key=None)

check_system_usage()
# Out:
# scGPT - INFO - Binning data ...
# CPU usage: 3.1%
# Memory usage: 7.4%
# GPU 0: NVIDIA A10G, 0.0% load, 4.0MB used of 23028.0MB
# Execution time: 0.029104232788085938 seconds

# %%
data_combined = np.concatenate([adata.layers["X_binned"], adata_protein.layers["X_binned"]], axis=1)
adata = AnnData(
    X=data_combined,
    obs=adata.obs,
    var=pd.DataFrame(index=adata.var_names.tolist() + adata_protein.var_names.tolist()),
    layers={"X_binned": data_combined,}
)
adata.var["gene_name"] = adata.var.index.tolist()

# %%
if config['per_seq_batch_sample']:
    # sort the adata by batch_id in advance
    adata_sorted = adata[adata.obs["batch_id"].argsort()].copy()

# %%
all_counts = (
    adata.layers[config['input_layer_key']].A
    if issparse(adata.layers[config['input_layer_key']])
    else adata.layers[config['input_layer_key']]
)
genes = adata.var["gene_name"].tolist()

celltypes_labels = adata.obs["celltype"].tolist()  # make sure count from 0
num_types = len(set(celltypes_labels))
celltypes_labels = np.array(celltypes_labels)

batch_ids = adata.obs["batch_id"].tolist()
num_batch_types = len(set(batch_ids))
batch_ids = np.array(batch_ids)

# %%
if config['use_mod']:
    mod_type = np.array([gene_loc_df.loc[g, 'mod'] for g in genes])
    vocab_mod = Vocab(VocabPybind(np.unique(gene_loc_df['mod']).tolist() + special_tokens, None))
    vocab_mod.set_default_index(vocab_mod["<pad>"])
    mod_type = np.array(vocab_mod(list(mod_type)), dtype=int)
    ntokens_mod = len(vocab_mod)
    print(mod_type)
# Out:
# [1 1 1 ... 0 0 0]

# %%
(
    train_data,
    valid_data,
    train_celltype_labels,
    valid_celltype_labels,
    train_batch_labels,
    valid_batch_labels,
) = train_test_split(
    all_counts, celltypes_labels, batch_ids, test_size=0.1, shuffle=True
)

# %%
num_of_non_zero_genes = [
    np.count_nonzero(train_data[i]) for i in range(train_data.shape[0])
]
print(f"max num of non_zero genes: {np.max(num_of_non_zero_genes)}")
print(f"min num of non_zero genes: {np.min(num_of_non_zero_genes)}")
print(f"average num of non_zero genes: {np.mean(num_of_non_zero_genes)}")
print(
    f"99% quantile num of non_zero genes: {np.quantile(num_of_non_zero_genes, 0.99)}"
)
print(f"max original values: {np.max(train_data)}")
print(
    f"average original non_zero values: {np.mean(train_data[np.nonzero(train_data)])}"
)
print(
    f"99% quantile original non_zero values: {np.quantile(train_data[np.nonzero(train_data)], 0.99)}"
)
print(f"num of celltypes: {num_types}")
# Out:
# max num of non_zero genes: 687
# min num of non_zero genes: 206
# average num of non_zero genes: 341.5295053003534
# 99% quantile num of non_zero genes: 510.0
# max original values: 50
# average original non_zero values: 25.3482856428962
# 99% quantile original non_zero values: 49.0
# num of celltypes: 17

# %%
if config['load_model'] is None:
    vocab = Vocab(VocabPybind(genes + special_tokens, None))
    vocab.set_default_index(vocab["<pad>"])
    gene_ids = np.array(vocab(genes), dtype=int)
else:
    pretrained_genes = [g for g in genes + special_tokens if g in old_vocab]
    new_genes = [g for g in genes + special_tokens if g not in old_vocab]
    gene_ids_pretrained = np.array(old_vocab(pretrained_genes), dtype=int)
    # https://discuss.pytorch.org/t/expand-an-existing-embedding-and-linear-layer-nan-loss-value/55670/2
    # Retrieve pretrained weights
    vocab = Vocab(VocabPybind(pretrained_genes + new_genes, None))
    vocab.set_default_index(vocab["<pad>"])
    gene_ids = np.array(vocab(genes), dtype=int)

# %%
tokenized_train = tokenize_and_pad_batch(
    train_data,
    gene_ids,
    max_len=config['max_seq_len'],
    vocab=vocab,
    pad_token=config['pad_token'],
    pad_value=config['pad_value'],
    append_cls=True,  # append <cls> token at the beginning
    include_zero_gene=config['include_zero_gene'],
    mod_type=mod_type if config['use_mod'] else None,
    vocab_mod=vocab_mod if config['use_mod'] else None,
)
tokenized_valid = tokenize_and_pad_batch(
    valid_data,
    gene_ids,
    max_len=config['max_seq_len'],
    vocab=vocab,
    pad_token=config['pad_token'],
    pad_value=config['pad_value'],
    append_cls=True,
    include_zero_gene=config['include_zero_gene'],
    mod_type=mod_type if config['use_mod'] else None,
    vocab_mod=vocab_mod if config['use_mod'] else None,
)
logger.info(
    f"train set number of samples: {tokenized_train['genes'].shape[0]}, "
    f"\n\t feature length: {tokenized_train['genes'].shape[1]}"
)
logger.info(
    f"valid set number of samples: {tokenized_valid['genes'].shape[0]}, "
    f"\n\t feature length: {tokenized_valid['genes'].shape[1]}"
)
# Out:
# scGPT - INFO - train set number of samples: 11320,
# 	 feature length: 688
# scGPT - INFO - valid set number of samples: 1258,
# 	 feature length: 663

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model_dict = torch.load(model_file)
ntokens = len(vocab)  # size of vocabulary
model = MultiOmicTransformerModel(
    ntokens,
    embsize,
    nhead,
    d_hid, 
    nlayers,
    vocab=vocab,
    dropout=config['dropout'],
    pad_token=config['pad_token'],
    pad_value=config['pad_value'],
    do_mvc=config['GEPC'],
    do_dab=config['DAR'],
    use_batch_labels=config['use_batch_labels'],
    num_batch_labels=num_batch_types,
    domain_spec_batchnorm=config['DSBN'],
    n_input_bins=config['n_bins'],
    ecs_threshold=config['ecs_thres'],
    explicit_zero_prob=config['explicit_zero_prob'],
    use_fast_transformer=config['fast_transformer'],
    pre_norm=config['pre_norm'],
    use_mod=config['use_mod'],
    ntokens_mod=ntokens_mod if config['use_mod'] else None,
    vocab_mod=vocab_mod if config['use_mod'] else None,
)

with torch.no_grad():
    pretrained_emb_weights = model_dict['encoder.embedding.weight'][gene_ids_pretrained, :]
    model.encoder.embedding.weight.data[:len(pretrained_genes), :] = pretrained_emb_weights
    model.encoder.enc_norm.weight.data = model_dict['encoder.enc_norm.weight']
ntokens = len(vocab)

model.to(device)
#wandb.watch(model)
print(model)
check_system_usage()
# Out:
# MultiOmicTransformerModel(
#   (encoder): GeneEncoder(
#     (embedding): Embedding(1337, 512, padding_idx=1089)
#     (enc_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#   )
#   (value_encoder): ContinuousValueEncoder(
#     (dropout): Dropout(p=0.2, inplace=False)
#     (linear1): Linear(in_features=1, out_features=512, bias=True)
#     (activation): ReLU()
#     (linear2): Linear(in_features=512, out_features=512, bias=True)
#     (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#   )
#   (batch_encoder): BatchLabelEncoder(
#     (embedding): Embedding(3, 512)
#     (enc_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#   )
#   (mod_encoder): BatchLabelEncoder(
#     (embedding): Embedding(5, 512, padding_idx=2)
#     (enc_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#   )
#   (transformer_encoder): TransformerEncoder(
#     (layers): ModuleList(
#       (0-3): 4 x FlashTransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (dropout): Dropout(p=0.2, inplace=False)
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.2, inplace=False)
#         (dropout2): Dropout(p=0.2, inplace=False)
#       )
#     )
#   )
#   (decoder): ExprDecoder(
#     (fc): Sequential(
#       (0): Linear(in_features=1024, out_features=512, bias=True)
#       (1): LeakyReLU(negative_slope=0.01)
#       (2): Linear(in_features=512, out_features=512, bias=True)
#       (3): LeakyReLU(negative_slope=0.01)
#       (4): Linear(in_features=512, out_features=1, bias=True)
#     )
#   )
#   (cls_decoder): ClsDecoder(
#     (_decoder): ModuleList(
#       (0): Linear(in_features=512, out_features=512, bias=True)
#       (1): ReLU()
#       (2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       (3): Linear(in_features=512, out_features=512, bias=True)
#       (4): ReLU()
#       (5): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#     )
#     (out_layer): Linear(in_features=512, out_features=1, bias=True)
#   )
#   (mvc_decoder): MVCDecoder(
#     (gene2query): Linear(in_features=1024, out_features=1024, bias=True)
#     (query_activation): Sigmoid()
#     (W): Linear(in_features=1024, out_features=1024, bias=False)
#   )
#   (grad_reverse_discriminator): AdversarialDiscriminator(
#     (_decoder): ModuleList(
#       (0): Linear(in_features=512, out_features=512, bias=True)
#       (1): LeakyReLU(negative_slope=0.01)
#       (2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       (3): Linear(in_features=512, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.01)
#       (5): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#     )
#     (out_layer): Linear(in_features=512, out_features=3, bias=True)
#   )
#   (sim): Similarity(
#     (cos): CosineSimilarity()
#   )
#   (creterion_cce): CrossEntropyLoss()
# )
# CPU usage: 4.0%
# Memory usage: 8.0%
# GPU 0: NVIDIA A10G, 6.0% load, 559.0MB used of 23028.0MB
# Execution time: 0.024808406829833984 seconds

# %%
if config['GEP'] and config['GEPC']:
    criterion_gep_gepc = masked_mse_loss
if config['CLS']:
    criterion_cls = nn.CrossEntropyLoss()
if config['DAR']:
    criterion_dab = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(
    model.parameters(), lr=config['lr'], eps=1e-4 if config['amp'] else 1e-8
)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 1, gamma=config['schedule_ratio'])
scaler = torch.cuda.amp.GradScaler(enabled=config['amp'])

# %%
#FineTuning
best_val_loss = float("inf")
best_avg_bio = 0.0
best_model = None
batch_first = True
#define_wandb_metrcis()

for epoch in range(1, config['epochs'] + 1):
    epoch_start_time = time.time()
    train_data_pt, valid_data_pt = prepare_data(
        tokenized_train=tokenized_train, 
        tokenized_valid=tokenized_valid, 
        train_batch_labels=train_batch_labels,
        valid_batch_labels=valid_batch_labels,
        config=config,
        epoch=epoch,
        sort_seq_batch=config['per_seq_batch_sample'])
    
    train_loader = prepare_dataloader(
        train_data_pt,
        batch_size=config['batch_size'],
        shuffle=True,
        intra_domain_shuffle=False,
        drop_last=False,
        per_seq_batch_sample=config['per_seq_batch_sample']
    )
    valid_loader = prepare_dataloader(
        valid_data_pt,
        batch_size=config['batch_size'],
        shuffle=False,
        intra_domain_shuffle=False,
        drop_last=False,
        per_seq_batch_sample=config['per_seq_batch_sample']
    )

    if config['do_train']:
        train(
            model=model,
            loader=train_loader,
            vocab=vocab,
            criterion_gep_gepc=criterion_gep_gepc if config['GEP'] and config['GEPC'] else None,
            criterion_dab=criterion_dab if config['DAR'] else None,
            criterion_cls=criterion_cls if config['CLS'] else None,
            scaler=scaler,
            optimizer=optimizer,
            scheduler=scheduler,
            device=device,
            config=config,
            logger=logger,
            epoch=epoch,
        )
    val_loss = evaluate(
        model=model,
        loader=valid_loader,
        vocab=vocab,
        criterion_gep_gepc=criterion_gep_gepc if config['GEP'] and config['GEPC'] else None,
        criterion_dab=criterion_dab if config['DAR'] else None,
        criterion_cls=criterion_cls if config['CLS'] else None,
        device=device,
        config=config,
        epoch=epoch
    )
    elapsed = time.time() - epoch_start_time
    logger.info("-" * 89)
    logger.info(
        f"| end of epoch {epoch:3d} | time: {elapsed:5.2f}s | "
        f"valid loss {val_loss:5.4f} | "
    )
    logger.info("-" * 89)

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_model = copy.deepcopy(model)
        best_model_epoch = epoch
        logger.info(f"Best model with score {best_val_loss:5.4f}")

    if epoch % config['save_eval_interval'] == 0 or epoch == config['epochs']:
        logger.info(f"Saving model to {save_dir}")
        torch.save(best_model.state_dict(), save_dir / f"model_e{best_model_epoch}.pt")

        # eval on testdata
        results = eval_testdata(
            model = best_model,
            adata_t = adata_sorted if config['per_seq_batch_sample'] else adata,
            gene_ids = gene_ids,
            vocab = vocab,
            config = config,
            logger = logger,
            include_types=["cls"],
        )
        results["batch_umap"].savefig(
            save_dir / f"embeddings_batch_umap[cls]_e{best_model_epoch}.png", dpi=300
        )

        results["celltype_umap"].savefig(
            save_dir / f"embeddings_celltype_umap[cls]_e{best_model_epoch}.png", dpi=300
        )
        metrics_to_log = {"test/" + k: v for k, v in results.items()}
        # metrics_to_log["test/batch_umap"] = wandb.Image(
        #     str(save_dir / f"embeddings_batch_umap[cls]_e{best_model_epoch}.png"),
        #     caption=f"celltype avg_bio epoch {best_model_epoch}",
        # )

        # metrics_to_log["test/celltype_umap"] = wandb.Image(
        #     str(save_dir / f"embeddings_celltype_umap[cls]_e{best_model_epoch}.png"),
        #     caption=f"celltype avg_bio epoch {best_model_epoch}",
        # )
        metrics_to_log["test/best_model_epoch"] = best_model_epoch
        
    scheduler.step()
check_system_usage()
# Out:
# random masking at epoch   1, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch   1 | 100/708 batches | lr 0.00100 | ms/batch 85.03 | loss 11331.95 | gep 381.17 |gepc 10949.60 |dar  1.18 |
# scGPT - INFO - | epoch   1 | 200/708 batches | lr 0.00100 | ms/batch 81.05 | loss 280.12 | gep 201.90 |gepc 77.20 |dar  1.02 |
# scGPT - INFO - | epoch   1 | 300/708 batches | lr 0.00100 | ms/batch 81.06 | loss 277.33 | gep 201.65 |gepc 74.71 |dar  0.97 |
# scGPT - INFO - | epoch   1 | 400/708 batches | lr 0.00100 | ms/batch 81.05 | loss 278.71 | gep 202.60 |gepc 75.13 |dar  0.98 |
# scGPT - INFO - | epoch   1 | 500/708 batches | lr 0.00100 | ms/batch 81.04 | loss 276.19 | gep 202.01 |gepc 73.22 |dar  0.96 |
# scGPT - INFO - | epoch   1 | 600/708 batches | lr 0.00100 | ms/batch 81.07 | loss 275.99 | gep 200.93 |gepc 74.06 |dar  1.00 |
# scGPT - INFO - | epoch   1 | 700/708 batches | lr 0.00100 | ms/batch 81.07 | loss 276.45 | gep 202.13 |gepc 73.36 |dar  0.96 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch   1 | time: 59.95s | valid loss 201.6557 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Best model with score 201.6557
# random masking at epoch   2, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch   2 | 100/708 batches | lr 0.00095 | ms/batch 81.91 | loss 278.63 | gep 203.74 |gepc 73.92 |dar  0.97 |
# scGPT - INFO - | epoch   2 | 200/708 batches | lr 0.00095 | ms/batch 81.09 | loss 276.16 | gep 202.35 |gepc 72.82 |dar  0.99 |
# scGPT - INFO - | epoch   2 | 300/708 batches | lr 0.00095 | ms/batch 81.12 | loss 275.14 | gep 201.91 |gepc 72.29 |dar  0.94 |
# scGPT - INFO - | epoch   2 | 400/708 batches | lr 0.00095 | ms/batch 81.17 | loss 276.73 | gep 201.60 |gepc 74.15 |dar  0.98 |
# scGPT - INFO - | epoch   2 | 500/708 batches | lr 0.00095 | ms/batch 81.11 | loss 245.25 | gep 170.60 |gepc 73.67 |dar  0.97 |
# scGPT - INFO - | epoch   2 | 600/708 batches | lr 0.00095 | ms/batch 81.12 | loss 157.84 | gep 83.65 |gepc 73.26 |dar  0.93 |
# scGPT - INFO - | epoch   2 | 700/708 batches | lr 0.00095 | ms/batch 81.13 | loss 134.90 | gep 69.75 |gepc 64.30 |dar  0.85 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch   2 | time: 59.65s | valid loss 64.9525 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Best model with score 64.9525
# random masking at epoch   3, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch   3 | 100/708 batches | lr 0.00090 | ms/batch 81.93 | loss 127.00 | gep 65.10 |gepc 61.04 |dar  0.86 |
# scGPT - INFO - | epoch   3 | 200/708 batches | lr 0.00090 | ms/batch 81.13 | loss 125.66 | gep 63.96 |gepc 60.90 |dar  0.81 |
# scGPT - INFO - | epoch   3 | 300/708 batches | lr 0.00090 | ms/batch 81.12 | loss 124.29 | gep 63.20 |gepc 60.34 |dar  0.75 |
# scGPT - INFO - | epoch   3 | 400/708 batches | lr 0.00090 | ms/batch 81.09 | loss 123.21 | gep 62.44 |gepc 59.99 |dar  0.77 |
# scGPT - INFO - | epoch   3 | 500/708 batches | lr 0.00090 | ms/batch 81.08 | loss 123.23 | gep 62.50 |gepc 59.98 |dar  0.75 |
# scGPT - INFO - | epoch   3 | 600/708 batches | lr 0.00090 | ms/batch 81.07 | loss 121.06 | gep 61.36 |gepc 58.94 |dar  0.76 |
# scGPT - INFO - | epoch   3 | 700/708 batches | lr 0.00090 | ms/batch 81.11 | loss 120.17 | gep 60.43 |gepc 59.02 |dar  0.72 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch   3 | time: 59.64s | valid loss 60.1921 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Best model with score 60.1921
# random masking at epoch   4, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch   4 | 100/708 batches | lr 0.00086 | ms/batch 81.91 | loss 121.20 | gep 61.00 |gepc 59.47 |dar  0.73 |
# scGPT - INFO - | epoch   4 | 200/708 batches | lr 0.00086 | ms/batch 81.09 | loss 116.40 | gep 58.25 |gepc 57.40 |dar  0.75 |
# scGPT - INFO - | epoch   4 | 300/708 batches | lr 0.00086 | ms/batch 81.11 | loss 117.32 | gep 58.68 |gepc 57.90 |dar  0.74 |
# scGPT - INFO - | epoch   4 | 400/708 batches | lr 0.00086 | ms/batch 81.15 | loss 115.27 | gep 57.62 |gepc 56.94 |dar  0.72 |
# scGPT - INFO - | epoch   4 | 500/708 batches | lr 0.00086 | ms/batch 81.09 | loss 114.33 | gep 57.15 |gepc 56.47 |dar  0.71 |
# scGPT - INFO - | epoch   4 | 600/708 batches | lr 0.00086 | ms/batch 81.10 | loss 116.03 | gep 57.69 |gepc 57.59 |dar  0.74 |
# scGPT - INFO - | epoch   4 | 700/708 batches | lr 0.00086 | ms/batch 81.10 | loss 115.92 | gep 57.85 |gepc 57.39 |dar  0.67 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch   4 | time: 59.64s | valid loss 56.6196 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Best model with score 56.6196
# random masking at epoch   5, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch   5 | 100/708 batches | lr 0.00081 | ms/batch 81.93 | loss 113.91 | gep 56.81 |gepc 56.38 |dar  0.72 |
# scGPT - INFO - | epoch   5 | 200/708 batches | lr 0.00081 | ms/batch 81.05 | loss 112.93 | gep 56.43 |gepc 55.79 |dar  0.71 |
# scGPT - INFO - | epoch   5 | 300/708 batches | lr 0.00081 | ms/batch 81.09 | loss 113.06 | gep 56.43 |gepc 55.92 |dar  0.72 |
# scGPT - INFO - | epoch   5 | 400/708 batches | lr 0.00081 | ms/batch 81.04 | loss 112.91 | gep 56.16 |gepc 56.04 |dar  0.71 |
# scGPT - INFO - | epoch   5 | 500/708 batches | lr 0.00081 | ms/batch 81.09 | loss 112.68 | gep 56.07 |gepc 55.90 |dar  0.71 |
# scGPT - INFO - | epoch   5 | 600/708 batches | lr 0.00081 | ms/batch 81.06 | loss 111.03 | gep 55.26 |gepc 55.09 |dar  0.68 |
# scGPT - INFO - | epoch   5 | 700/708 batches | lr 0.00081 | ms/batch 81.04 | loss 110.12 | gep 54.82 |gepc 54.65 |dar  0.66 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch   5 | time: 59.62s | valid loss 56.0092 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Best model with score 56.0092
# scGPT - INFO - Saving model to save/dev_BMMC-Nov20-05-05
# scGPT - INFO - Evaluating cls cell embeddings
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 787/787 [00:20<00:00, 39.00it/s]
# NMI...
# ARI...
# Silhouette score...
# PC regression...
# Graph connectivity...
# scGPT - INFO -                                   0
# NMI_cluster/label          0.660623
# ARI_cluster/label          0.692170
# ASW_label                  0.647901
# ASW_label/batch            0.776850
# PCR_batch                  0.168588
# cell_cycle_conservation         NaN
# isolated_label_F1               NaN
# isolated_label_silhouette       NaN
# graph_conn                 0.726984
# kBET                            NaN
# iLISI                           NaN
# cLISI                           NaN
# hvg_overlap                     NaN
# trajectory                      NaN
# scGPT - INFO - Biological Conservation Metrics:
# ASW (cell-type): 0.6479, graph cLISI: nan, isolated label silhouette: nan,
# Batch Effect Removal Metrics:
# PCR_batch: 0.1686, ASW (batch): 0.7769, graph connectivity: 0.7270, graph iLISI: nan
# random masking at epoch   6, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch   6 | 100/708 batches | lr 0.00077 | ms/batch 82.00 | loss 111.98 | gep 55.75 |gepc 55.52 |dar  0.71 |
# scGPT - INFO - | epoch   6 | 200/708 batches | lr 0.00077 | ms/batch 81.19 | loss 108.71 | gep 54.06 |gepc 53.97 |dar  0.68 |
# scGPT - INFO - | epoch   6 | 300/708 batches | lr 0.00077 | ms/batch 81.20 | loss 109.55 | gep 54.52 |gepc 54.36 |dar  0.67 |
# scGPT - INFO - | epoch   6 | 400/708 batches | lr 0.00077 | ms/batch 81.18 | loss 109.56 | gep 54.44 |gepc 54.50 |dar  0.61 |
# scGPT - INFO - | epoch   6 | 500/708 batches | lr 0.00077 | ms/batch 81.16 | loss 107.88 | gep 53.75 |gepc 53.49 |dar  0.64 |
# scGPT - INFO - | epoch   6 | 600/708 batches | lr 0.00077 | ms/batch 81.18 | loss 109.78 | gep 54.53 |gepc 54.62 |dar  0.64 |
# scGPT - INFO - | epoch   6 | 700/708 batches | lr 0.00077 | ms/batch 81.20 | loss 108.49 | gep 53.79 |gepc 54.02 |dar  0.68 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch   6 | time: 59.70s | valid loss 55.3380 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Best model with score 55.3380
# random masking at epoch   7, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch   7 | 100/708 batches | lr 0.00074 | ms/batch 82.01 | loss 108.55 | gep 53.84 |gepc 53.98 |dar  0.73 |
# scGPT - INFO - | epoch   7 | 200/708 batches | lr 0.00074 | ms/batch 81.19 | loss 108.99 | gep 53.99 |gepc 54.38 |dar  0.62 |
# scGPT - INFO - | epoch   7 | 300/708 batches | lr 0.00074 | ms/batch 81.19 | loss 106.04 | gep 52.66 |gepc 52.75 |dar  0.63 |
# scGPT - INFO - | epoch   7 | 400/708 batches | lr 0.00074 | ms/batch 81.18 | loss 108.73 | gep 53.85 |gepc 54.21 |dar  0.67 |
# scGPT - INFO - | epoch   7 | 500/708 batches | lr 0.00074 | ms/batch 81.21 | loss 108.74 | gep 53.84 |gepc 54.24 |dar  0.66 |
# scGPT - INFO - | epoch   7 | 600/708 batches | lr 0.00074 | ms/batch 81.19 | loss 107.87 | gep 53.51 |gepc 53.71 |dar  0.65 |
# scGPT - INFO - | epoch   7 | 700/708 batches | lr 0.00074 | ms/batch 81.17 | loss 107.42 | gep 53.17 |gepc 53.60 |dar  0.66 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch   7 | time: 59.70s | valid loss 56.1456 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# random masking at epoch   8, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch   8 | 100/708 batches | lr 0.00070 | ms/batch 82.00 | loss 107.16 | gep 52.96 |gepc 53.53 |dar  0.67 |
# scGPT - INFO - | epoch   8 | 200/708 batches | lr 0.00070 | ms/batch 81.21 | loss 106.15 | gep 52.51 |gepc 53.02 |dar  0.63 |
# scGPT - INFO - | epoch   8 | 300/708 batches | lr 0.00070 | ms/batch 81.20 | loss 107.20 | gep 53.00 |gepc 53.53 |dar  0.67 |
# scGPT - INFO - | epoch   8 | 400/708 batches | lr 0.00070 | ms/batch 81.18 | loss 107.55 | gep 53.25 |gepc 53.64 |dar  0.66 |
# scGPT - INFO - | epoch   8 | 500/708 batches | lr 0.00070 | ms/batch 81.17 | loss 106.39 | gep 52.55 |gepc 53.18 |dar  0.66 |
# scGPT - INFO - | epoch   8 | 600/708 batches | lr 0.00070 | ms/batch 81.17 | loss 107.35 | gep 53.12 |gepc 53.60 |dar  0.63 |
# scGPT - INFO - | epoch   8 | 700/708 batches | lr 0.00070 | ms/batch 81.18 | loss 105.77 | gep 52.49 |gepc 52.66 |dar  0.61 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch   8 | time: 59.70s | valid loss 53.6437 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Best model with score 53.6437
# random masking at epoch   9, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch   9 | 100/708 batches | lr 0.00066 | ms/batch 82.01 | loss 106.18 | gep 52.52 |gepc 52.99 |dar  0.68 |
# scGPT - INFO - | epoch   9 | 200/708 batches | lr 0.00066 | ms/batch 81.13 | loss 106.66 | gep 52.80 |gepc 53.21 |dar  0.65 |
# scGPT - INFO - | epoch   9 | 300/708 batches | lr 0.00066 | ms/batch 81.14 | loss 104.60 | gep 51.83 |gepc 52.08 |dar  0.69 |
# scGPT - INFO - | epoch   9 | 400/708 batches | lr 0.00066 | ms/batch 81.17 | loss 105.35 | gep 52.11 |gepc 52.57 |dar  0.67 |
# scGPT - INFO - | epoch   9 | 500/708 batches | lr 0.00066 | ms/batch 81.13 | loss 105.74 | gep 52.39 |gepc 52.73 |dar  0.62 |
# scGPT - INFO - | epoch   9 | 600/708 batches | lr 0.00066 | ms/batch 81.12 | loss 103.12 | gep 51.02 |gepc 51.45 |dar  0.65 |
# scGPT - INFO - | epoch   9 | 700/708 batches | lr 0.00066 | ms/batch 81.14 | loss 105.08 | gep 52.11 |gepc 52.33 |dar  0.64 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch   9 | time: 59.67s | valid loss 52.6154 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Best model with score 52.6154
# random masking at epoch  10, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  10 | 100/708 batches | lr 0.00063 | ms/batch 82.00 | loss 106.60 | gep 52.72 |gepc 53.19 |dar  0.69 |
# scGPT - INFO - | epoch  10 | 200/708 batches | lr 0.00063 | ms/batch 81.18 | loss 104.80 | gep 51.93 |gepc 52.18 |dar  0.68 |
# scGPT - INFO - | epoch  10 | 300/708 batches | lr 0.00063 | ms/batch 81.21 | loss 104.24 | gep 51.65 |gepc 51.95 |dar  0.65 |
# scGPT - INFO - | epoch  10 | 400/708 batches | lr 0.00063 | ms/batch 81.19 | loss 106.29 | gep 52.66 |gepc 52.97 |dar  0.66 |
# scGPT - INFO - | epoch  10 | 500/708 batches | lr 0.00063 | ms/batch 81.20 | loss 103.55 | gep 51.35 |gepc 51.57 |dar  0.63 |
# scGPT - INFO - | epoch  10 | 600/708 batches | lr 0.00063 | ms/batch 81.21 | loss 103.23 | gep 51.02 |gepc 51.57 |dar  0.65 |
# scGPT - INFO - | epoch  10 | 700/708 batches | lr 0.00063 | ms/batch 81.19 | loss 103.38 | gep 51.15 |gepc 51.55 |dar  0.68 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  10 | time: 59.71s | valid loss 51.7078 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Best model with score 51.7078
# scGPT - INFO - Saving model to save/dev_BMMC-Nov20-05-05
# scGPT - INFO - Evaluating cls cell embeddings
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 787/787 [00:20<00:00, 39.08it/s]
# NMI...
# ARI...
# Silhouette score...
# PC regression...
# Graph connectivity...
# scGPT - INFO -                                   0
# NMI_cluster/label          0.685408
# ARI_cluster/label          0.734269
# ASW_label                  0.654964
# ASW_label/batch            0.798482
# PCR_batch                  0.285679
# cell_cycle_conservation         NaN
# isolated_label_F1               NaN
# isolated_label_silhouette       NaN
# graph_conn                 0.914654
# kBET                            NaN
# iLISI                           NaN
# cLISI                           NaN
# hvg_overlap                     NaN
# trajectory                      NaN
# scGPT - INFO - Biological Conservation Metrics:
# ASW (cell-type): 0.6550, graph cLISI: nan, isolated label silhouette: nan,
# Batch Effect Removal Metrics:
# PCR_batch: 0.2857, ASW (batch): 0.7985, graph connectivity: 0.9147, graph iLISI: nan
# random masking at epoch  11, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  11 | 100/708 batches | lr 0.00060 | ms/batch 81.98 | loss 105.64 | gep 52.28 |gepc 52.69 |dar  0.67 |
# scGPT - INFO - | epoch  11 | 200/708 batches | lr 0.00060 | ms/batch 81.17 | loss 102.54 | gep 50.64 |gepc 51.24 |dar  0.67 |
# scGPT - INFO - | epoch  11 | 300/708 batches | lr 0.00060 | ms/batch 81.15 | loss 103.58 | gep 51.31 |gepc 51.60 |dar  0.68 |
# scGPT - INFO - | epoch  11 | 400/708 batches | lr 0.00060 | ms/batch 81.16 | loss 103.67 | gep 51.35 |gepc 51.70 |dar  0.62 |
# scGPT - INFO - | epoch  11 | 500/708 batches | lr 0.00060 | ms/batch 81.18 | loss 104.09 | gep 51.41 |gepc 52.00 |dar  0.67 |
# scGPT - INFO - | epoch  11 | 600/708 batches | lr 0.00060 | ms/batch 81.17 | loss 104.56 | gep 51.64 |gepc 52.25 |dar  0.66 |
# scGPT - INFO - | epoch  11 | 700/708 batches | lr 0.00060 | ms/batch 81.16 | loss 103.26 | gep 51.01 |gepc 51.52 |dar  0.72 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  11 | time: 59.69s | valid loss 51.0172 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Best model with score 51.0172
# random masking at epoch  12, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  12 | 100/708 batches | lr 0.00057 | ms/batch 82.01 | loss 104.13 | gep 51.50 |gepc 52.00 |dar  0.63 |
# scGPT - INFO - | epoch  12 | 200/708 batches | lr 0.00057 | ms/batch 81.17 | loss 102.46 | gep 50.67 |gepc 51.13 |dar  0.66 |
# scGPT - INFO - | epoch  12 | 300/708 batches | lr 0.00057 | ms/batch 81.18 | loss 102.42 | gep 50.60 |gepc 51.15 |dar  0.67 |
# scGPT - INFO - | epoch  12 | 400/708 batches | lr 0.00057 | ms/batch 81.16 | loss 103.09 | gep 50.93 |gepc 51.47 |dar  0.69 |
# scGPT - INFO - | epoch  12 | 500/708 batches | lr 0.00057 | ms/batch 81.17 | loss 103.18 | gep 51.05 |gepc 51.45 |dar  0.67 |
# scGPT - INFO - | epoch  12 | 600/708 batches | lr 0.00057 | ms/batch 81.19 | loss 103.36 | gep 51.20 |gepc 51.52 |dar  0.64 |
# scGPT - INFO - | epoch  12 | 700/708 batches | lr 0.00057 | ms/batch 81.17 | loss 103.59 | gep 51.16 |gepc 51.74 |dar  0.70 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  12 | time: 59.69s | valid loss 53.1581 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# random masking at epoch  13, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  13 | 100/708 batches | lr 0.00054 | ms/batch 82.06 | loss 103.76 | gep 51.31 |gepc 51.80 |dar  0.66 |
# scGPT - INFO - | epoch  13 | 200/708 batches | lr 0.00054 | ms/batch 81.22 | loss 100.77 | gep 49.87 |gepc 50.24 |dar  0.66 |
# scGPT - INFO - | epoch  13 | 300/708 batches | lr 0.00054 | ms/batch 81.24 | loss 102.67 | gep 50.81 |gepc 51.20 |dar  0.65 |
# scGPT - INFO - | epoch  13 | 400/708 batches | lr 0.00054 | ms/batch 81.22 | loss 102.78 | gep 50.66 |gepc 51.47 |dar  0.65 |
# scGPT - INFO - | epoch  13 | 500/708 batches | lr 0.00054 | ms/batch 81.23 | loss 102.06 | gep 50.38 |gepc 51.03 |dar  0.65 |
# scGPT - INFO - | epoch  13 | 600/708 batches | lr 0.00054 | ms/batch 81.23 | loss 103.30 | gep 51.11 |gepc 51.52 |dar  0.68 |
# scGPT - INFO - | epoch  13 | 700/708 batches | lr 0.00054 | ms/batch 81.23 | loss 102.28 | gep 50.56 |gepc 51.04 |dar  0.69 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  13 | time: 59.73s | valid loss 52.5792 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# random masking at epoch  14, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  14 | 100/708 batches | lr 0.00051 | ms/batch 82.03 | loss 103.08 | gep 50.78 |gepc 51.64 |dar  0.67 |
# scGPT - INFO - | epoch  14 | 200/708 batches | lr 0.00051 | ms/batch 81.19 | loss 101.44 | gep 50.06 |gepc 50.72 |dar  0.67 |
# scGPT - INFO - | epoch  14 | 300/708 batches | lr 0.00051 | ms/batch 81.20 | loss 101.35 | gep 50.07 |gepc 50.60 |dar  0.68 |
# scGPT - INFO - | epoch  14 | 400/708 batches | lr 0.00051 | ms/batch 81.21 | loss 101.31 | gep 50.09 |gepc 50.54 |dar  0.68 |
# scGPT - INFO - | epoch  14 | 500/708 batches | lr 0.00051 | ms/batch 81.22 | loss 101.34 | gep 50.08 |gepc 50.57 |dar  0.69 |
# scGPT - INFO - | epoch  14 | 600/708 batches | lr 0.00051 | ms/batch 81.19 | loss 103.82 | gep 51.29 |gepc 51.85 |dar  0.67 |
# scGPT - INFO - | epoch  14 | 700/708 batches | lr 0.00051 | ms/batch 81.20 | loss 101.82 | gep 50.32 |gepc 50.83 |dar  0.66 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  14 | time: 59.71s | valid loss 52.2922 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# random masking at epoch  15, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  15 | 100/708 batches | lr 0.00049 | ms/batch 82.01 | loss 101.32 | gep 50.06 |gepc 50.58 |dar  0.68 |
# scGPT - INFO - | epoch  15 | 200/708 batches | lr 0.00049 | ms/batch 81.18 | loss 100.89 | gep 49.88 |gepc 50.36 |dar  0.66 |
# scGPT - INFO - | epoch  15 | 300/708 batches | lr 0.00049 | ms/batch 81.19 | loss 101.62 | gep 50.19 |gepc 50.77 |dar  0.67 |
# scGPT - INFO - | epoch  15 | 400/708 batches | lr 0.00049 | ms/batch 81.18 | loss 101.46 | gep 50.19 |gepc 50.65 |dar  0.63 |
# scGPT - INFO - | epoch  15 | 500/708 batches | lr 0.00049 | ms/batch 81.18 | loss 99.81 | gep 49.30 |gepc 49.81 |dar  0.70 |
# scGPT - INFO - | epoch  15 | 600/708 batches | lr 0.00049 | ms/batch 81.16 | loss 101.93 | gep 50.37 |gepc 50.91 |dar  0.65 |
# scGPT - INFO - | epoch  15 | 700/708 batches | lr 0.00049 | ms/batch 81.20 | loss 102.70 | gep 50.75 |gepc 51.23 |dar  0.72 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  15 | time: 59.69s | valid loss 51.6361 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Saving model to save/dev_BMMC-Nov20-05-05
# scGPT - INFO - Evaluating cls cell embeddings
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 787/787 [00:20<00:00, 39.02it/s]
# NMI...
# ARI...
# Silhouette score...
# PC regression...
# Graph connectivity...
# scGPT - INFO -                                   0
# NMI_cluster/label          0.698077
# ARI_cluster/label          0.734537
# ASW_label                  0.645819
# ASW_label/batch            0.815585
# PCR_batch                  0.301478
# cell_cycle_conservation         NaN
# isolated_label_F1               NaN
# isolated_label_silhouette       NaN
# graph_conn                 0.868531
# kBET                            NaN
# iLISI                           NaN
# cLISI                           NaN
# hvg_overlap                     NaN
# trajectory                      NaN
# scGPT - INFO - Biological Conservation Metrics:
# ASW (cell-type): 0.6458, graph cLISI: nan, isolated label silhouette: nan,
# Batch Effect Removal Metrics:
# PCR_batch: 0.3015, ASW (batch): 0.8156, graph connectivity: 0.8685, graph iLISI: nan
# random masking at epoch  16, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  16 | 100/708 batches | lr 0.00046 | ms/batch 81.99 | loss 102.01 | gep 50.36 |gepc 50.97 |dar  0.68 |
# scGPT - INFO - | epoch  16 | 200/708 batches | lr 0.00046 | ms/batch 81.16 | loss 100.72 | gep 49.85 |gepc 50.24 |dar  0.63 |
# scGPT - INFO - | epoch  16 | 300/708 batches | lr 0.00046 | ms/batch 81.20 | loss 102.65 | gep 50.79 |gepc 51.17 |dar  0.68 |
# scGPT - INFO - | epoch  16 | 400/708 batches | lr 0.00046 | ms/batch 81.17 | loss 100.32 | gep 49.59 |gepc 50.06 |dar  0.67 |
# scGPT - INFO - | epoch  16 | 500/708 batches | lr 0.00046 | ms/batch 81.14 | loss 99.89 | gep 49.30 |gepc 49.90 |dar  0.69 |
# scGPT - INFO - | epoch  16 | 600/708 batches | lr 0.00046 | ms/batch 81.18 | loss 100.54 | gep 49.68 |gepc 50.20 |dar  0.67 |
# scGPT - INFO - | epoch  16 | 700/708 batches | lr 0.00046 | ms/batch 81.18 | loss 99.86 | gep 49.39 |gepc 49.80 |dar  0.67 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  16 | time: 59.68s | valid loss 53.0062 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# random masking at epoch  17, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  17 | 100/708 batches | lr 0.00044 | ms/batch 82.00 | loss 100.37 | gep 49.56 |gepc 50.16 |dar  0.65 |
# scGPT - INFO - | epoch  17 | 200/708 batches | lr 0.00044 | ms/batch 81.17 | loss 101.08 | gep 49.91 |gepc 50.49 |dar  0.67 |
# scGPT - INFO - | epoch  17 | 300/708 batches | lr 0.00044 | ms/batch 81.18 | loss 102.06 | gep 50.47 |gepc 50.95 |dar  0.64 |
# scGPT - INFO - | epoch  17 | 400/708 batches | lr 0.00044 | ms/batch 81.20 | loss 100.64 | gep 49.73 |gepc 50.25 |dar  0.66 |
# scGPT - INFO - | epoch  17 | 500/708 batches | lr 0.00044 | ms/batch 81.17 | loss 100.53 | gep 49.72 |gepc 50.14 |dar  0.68 |
# scGPT - INFO - | epoch  17 | 600/708 batches | lr 0.00044 | ms/batch 81.22 | loss 101.71 | gep 50.28 |gepc 50.76 |dar  0.67 |
# scGPT - INFO - | epoch  17 | 700/708 batches | lr 0.00044 | ms/batch 81.11 | loss 99.44 | gep 49.16 |gepc 49.59 |dar  0.68 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  17 | time: 59.69s | valid loss 50.4996 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Best model with score 50.4996
# random masking at epoch  18, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  18 | 100/708 batches | lr 0.00042 | ms/batch 82.01 | loss 98.48 | gep 48.61 |gepc 49.18 |dar  0.69 |
# scGPT - INFO - | epoch  18 | 200/708 batches | lr 0.00042 | ms/batch 81.11 | loss 99.61 | gep 49.24 |gepc 49.69 |dar  0.68 |
# scGPT - INFO - | epoch  18 | 300/708 batches | lr 0.00042 | ms/batch 81.13 | loss 100.68 | gep 49.71 |gepc 50.30 |dar  0.68 |
# scGPT - INFO - | epoch  18 | 400/708 batches | lr 0.00042 | ms/batch 81.10 | loss 100.84 | gep 49.92 |gepc 50.25 |dar  0.66 |
# scGPT - INFO - | epoch  18 | 500/708 batches | lr 0.00042 | ms/batch 81.11 | loss 99.99 | gep 49.45 |gepc 49.90 |dar  0.64 |
# scGPT - INFO - | epoch  18 | 600/708 batches | lr 0.00042 | ms/batch 81.10 | loss 100.65 | gep 49.74 |gepc 50.22 |dar  0.68 |
# scGPT - INFO - | epoch  18 | 700/708 batches | lr 0.00042 | ms/batch 81.11 | loss 98.61 | gep 48.73 |gepc 49.23 |dar  0.65 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  18 | time: 59.66s | valid loss 50.9985 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# random masking at epoch  19, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  19 | 100/708 batches | lr 0.00040 | ms/batch 81.98 | loss 100.11 | gep 49.53 |gepc 49.88 |dar  0.70 |
# scGPT - INFO - | epoch  19 | 200/708 batches | lr 0.00040 | ms/batch 81.13 | loss 99.96 | gep 49.38 |gepc 49.93 |dar  0.65 |
# scGPT - INFO - | epoch  19 | 300/708 batches | lr 0.00040 | ms/batch 81.13 | loss 99.78 | gep 49.30 |gepc 49.82 |dar  0.66 |
# scGPT - INFO - | epoch  19 | 400/708 batches | lr 0.00040 | ms/batch 81.10 | loss 99.35 | gep 49.09 |gepc 49.58 |dar  0.68 |
# scGPT - INFO - | epoch  19 | 500/708 batches | lr 0.00040 | ms/batch 81.14 | loss 98.73 | gep 48.79 |gepc 49.25 |dar  0.69 |
# scGPT - INFO - | epoch  19 | 600/708 batches | lr 0.00040 | ms/batch 81.10 | loss 99.97 | gep 49.39 |gepc 49.90 |dar  0.69 |
# scGPT - INFO - | epoch  19 | 700/708 batches | lr 0.00040 | ms/batch 81.05 | loss 99.98 | gep 49.34 |gepc 49.95 |dar  0.70 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  19 | time: 59.64s | valid loss 50.6127 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# random masking at epoch  20, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  20 | 100/708 batches | lr 0.00038 | ms/batch 81.90 | loss 101.12 | gep 49.94 |gepc 50.50 |dar  0.68 |
# scGPT - INFO - | epoch  20 | 200/708 batches | lr 0.00038 | ms/batch 81.09 | loss 98.16 | gep 48.47 |gepc 48.97 |dar  0.71 |
# scGPT - INFO - | epoch  20 | 300/708 batches | lr 0.00038 | ms/batch 81.08 | loss 99.65 | gep 49.22 |gepc 49.75 |dar  0.68 |
# scGPT - INFO - | epoch  20 | 400/708 batches | lr 0.00038 | ms/batch 81.08 | loss 99.09 | gep 49.01 |gepc 49.42 |dar  0.66 |
# scGPT - INFO - | epoch  20 | 500/708 batches | lr 0.00038 | ms/batch 81.08 | loss 99.32 | gep 49.12 |gepc 49.51 |dar  0.69 |
# scGPT - INFO - | epoch  20 | 600/708 batches | lr 0.00038 | ms/batch 81.05 | loss 99.53 | gep 49.16 |gepc 49.74 |dar  0.63 |
# scGPT - INFO - | epoch  20 | 700/708 batches | lr 0.00038 | ms/batch 81.04 | loss 100.01 | gep 49.52 |gepc 49.86 |dar  0.62 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  20 | time: 59.62s | valid loss 51.1768 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Saving model to save/dev_BMMC-Nov20-05-05
# scGPT - INFO - Evaluating cls cell embeddings
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 787/787 [00:20<00:00, 39.03it/s]
# NMI...
# ARI...
# Silhouette score...
# PC regression...
# Graph connectivity...
# scGPT - INFO -                                   0
# NMI_cluster/label          0.754746
# ARI_cluster/label          0.889835
# ASW_label                  0.643353
# ASW_label/batch            0.835393
# PCR_batch                  0.315186
# cell_cycle_conservation         NaN
# isolated_label_F1               NaN
# isolated_label_silhouette       NaN
# graph_conn                 0.917632
# kBET                            NaN
# iLISI                           NaN
# cLISI                           NaN
# hvg_overlap                     NaN
# trajectory                      NaN
# scGPT - INFO - Biological Conservation Metrics:
# ASW (cell-type): 0.6434, graph cLISI: nan, isolated label silhouette: nan,
# Batch Effect Removal Metrics:
# PCR_batch: 0.3152, ASW (batch): 0.8354, graph connectivity: 0.9176, graph iLISI: nan
# random masking at epoch  21, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  21 | 100/708 batches | lr 0.00036 | ms/batch 81.85 | loss 99.56 | gep 49.17 |gepc 49.69 |dar  0.71 |
# scGPT - INFO - | epoch  21 | 200/708 batches | lr 0.00036 | ms/batch 81.04 | loss 98.51 | gep 48.77 |gepc 49.08 |dar  0.66 |
# scGPT - INFO - | epoch  21 | 300/708 batches | lr 0.00036 | ms/batch 81.02 | loss 98.95 | gep 48.94 |gepc 49.36 |dar  0.66 |
# scGPT - INFO - | epoch  21 | 400/708 batches | lr 0.00036 | ms/batch 81.02 | loss 99.85 | gep 49.36 |gepc 49.78 |dar  0.71 |
# scGPT - INFO - | epoch  21 | 500/708 batches | lr 0.00036 | ms/batch 81.03 | loss 97.84 | gep 48.35 |gepc 48.81 |dar  0.67 |
# scGPT - INFO - | epoch  21 | 600/708 batches | lr 0.00036 | ms/batch 81.03 | loss 97.81 | gep 48.39 |gepc 48.76 |dar  0.66 |
# scGPT - INFO - | epoch  21 | 700/708 batches | lr 0.00036 | ms/batch 81.01 | loss 98.47 | gep 48.71 |gepc 49.10 |dar  0.66 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  21 | time: 59.58s | valid loss 50.1245 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Best model with score 50.1245
# random masking at epoch  22, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  22 | 100/708 batches | lr 0.00034 | ms/batch 81.87 | loss 98.89 | gep 48.86 |gepc 49.33 |dar  0.70 |
# scGPT - INFO - | epoch  22 | 200/708 batches | lr 0.00034 | ms/batch 81.03 | loss 98.79 | gep 48.81 |gepc 49.30 |dar  0.68 |
# scGPT - INFO - | epoch  22 | 300/708 batches | lr 0.00034 | ms/batch 81.04 | loss 98.72 | gep 48.78 |gepc 49.27 |dar  0.66 |
# scGPT - INFO - | epoch  22 | 400/708 batches | lr 0.00034 | ms/batch 81.04 | loss 98.51 | gep 48.70 |gepc 49.12 |dar  0.69 |
# scGPT - INFO - | epoch  22 | 500/708 batches | lr 0.00034 | ms/batch 81.05 | loss 97.38 | gep 48.15 |gepc 48.55 |dar  0.69 |
# scGPT - INFO - | epoch  22 | 600/708 batches | lr 0.00034 | ms/batch 81.05 | loss 98.18 | gep 48.56 |gepc 48.95 |dar  0.68 |
# scGPT - INFO - | epoch  22 | 700/708 batches | lr 0.00034 | ms/batch 81.05 | loss 99.29 | gep 49.08 |gepc 49.52 |dar  0.70 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  22 | time: 59.60s | valid loss 50.8963 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# random masking at epoch  23, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  23 | 100/708 batches | lr 0.00032 | ms/batch 82.06 | loss 99.26 | gep 49.01 |gepc 49.56 |dar  0.69 |
# scGPT - INFO - | epoch  23 | 200/708 batches | lr 0.00032 | ms/batch 81.26 | loss 97.84 | gep 48.38 |gepc 48.80 |dar  0.66 |
# scGPT - INFO - | epoch  23 | 300/708 batches | lr 0.00032 | ms/batch 81.15 | loss 98.54 | gep 48.77 |gepc 49.13 |dar  0.64 |
# scGPT - INFO - | epoch  23 | 400/708 batches | lr 0.00032 | ms/batch 81.06 | loss 97.91 | gep 48.35 |gepc 48.87 |dar  0.69 |
# scGPT - INFO - | epoch  23 | 500/708 batches | lr 0.00032 | ms/batch 81.05 | loss 98.29 | gep 48.61 |gepc 48.99 |dar  0.70 |
# scGPT - INFO - | epoch  23 | 600/708 batches | lr 0.00032 | ms/batch 81.06 | loss 98.81 | gep 48.81 |gepc 49.33 |dar  0.66 |
# scGPT - INFO - | epoch  23 | 700/708 batches | lr 0.00032 | ms/batch 81.08 | loss 97.64 | gep 48.17 |gepc 48.75 |dar  0.71 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  23 | time: 59.68s | valid loss 50.1556 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# random masking at epoch  24, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  24 | 100/708 batches | lr 0.00031 | ms/batch 81.94 | loss 97.67 | gep 48.21 |gepc 48.79 |dar  0.68 |
# scGPT - INFO - | epoch  24 | 200/708 batches | lr 0.00031 | ms/batch 81.10 | loss 99.85 | gep 49.32 |gepc 49.84 |dar  0.68 |
# scGPT - INFO - | epoch  24 | 300/708 batches | lr 0.00031 | ms/batch 81.07 | loss 96.92 | gep 47.95 |gepc 48.31 |dar  0.67 |
# scGPT - INFO - | epoch  24 | 400/708 batches | lr 0.00031 | ms/batch 81.12 | loss 97.56 | gep 48.29 |gepc 48.60 |dar  0.67 |
# scGPT - INFO - | epoch  24 | 500/708 batches | lr 0.00031 | ms/batch 81.09 | loss 97.19 | gep 48.05 |gepc 48.45 |dar  0.70 |
# scGPT - INFO - | epoch  24 | 600/708 batches | lr 0.00031 | ms/batch 81.12 | loss 97.82 | gep 48.31 |gepc 48.81 |dar  0.69 |
# scGPT - INFO - | epoch  24 | 700/708 batches | lr 0.00031 | ms/batch 81.10 | loss 98.58 | gep 48.71 |gepc 49.20 |dar  0.67 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  24 | time: 59.64s | valid loss 50.4491 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# random masking at epoch  25, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  25 | 100/708 batches | lr 0.00029 | ms/batch 82.00 | loss 98.91 | gep 48.89 |gepc 49.33 |dar  0.69 |
# scGPT - INFO - | epoch  25 | 200/708 batches | lr 0.00029 | ms/batch 81.28 | loss 97.66 | gep 48.26 |gepc 48.71 |dar  0.69 |
# scGPT - INFO - | epoch  25 | 300/708 batches | lr 0.00029 | ms/batch 81.13 | loss 97.12 | gep 47.96 |gepc 48.45 |dar  0.70 |
# scGPT - INFO - | epoch  25 | 400/708 batches | lr 0.00029 | ms/batch 81.24 | loss 96.78 | gep 47.83 |gepc 48.26 |dar  0.69 |
# scGPT - INFO - | epoch  25 | 500/708 batches | lr 0.00029 | ms/batch 81.19 | loss 97.47 | gep 48.20 |gepc 48.58 |dar  0.70 |
# scGPT - INFO - | epoch  25 | 600/708 batches | lr 0.00029 | ms/batch 81.19 | loss 97.48 | gep 48.20 |gepc 48.60 |dar  0.68 |
# scGPT - INFO - | epoch  25 | 700/708 batches | lr 0.00029 | ms/batch 81.17 | loss 98.14 | gep 48.54 |gepc 48.97 |dar  0.64 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  25 | time: 59.73s | valid loss 50.0105 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Best model with score 50.0105
# scGPT - INFO - Saving model to save/dev_BMMC-Nov20-05-05
# scGPT - INFO - Evaluating cls cell embeddings
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 787/787 [00:20<00:00, 38.88it/s]
# NMI...
# ARI...
# Silhouette score...
# PC regression...
# Graph connectivity...
# scGPT - INFO -                                   0
# NMI_cluster/label          0.760259
# ARI_cluster/label          0.908605
# ASW_label                  0.640584
# ASW_label/batch            0.873514
# PCR_batch                  0.382741
# cell_cycle_conservation         NaN
# isolated_label_F1               NaN
# isolated_label_silhouette       NaN
# graph_conn                 0.898290
# kBET                            NaN
# iLISI                           NaN
# cLISI                           NaN
# hvg_overlap                     NaN
# trajectory                      NaN
# scGPT - INFO - Biological Conservation Metrics:
# ASW (cell-type): 0.6406, graph cLISI: nan, isolated label silhouette: nan,
# Batch Effect Removal Metrics:
# PCR_batch: 0.3827, ASW (batch): 0.8735, graph connectivity: 0.8983, graph iLISI: nan
# CPU usage: 4.8%
# Memory usage: 9.6%
# GPU 0: NVIDIA A10G, 0.0% load, 3887.0MB used of 23028.0MB
# Execution time: 0.027263164520263672 seconds

# %%
metrics_to_log
# Out:
# {'test/NMI_cluster/label': 0.7602585403839945,
#  'test/ARI_cluster/label': 0.9086051929550253,
#  'test/ASW_label': 0.6405836045742035,
#  'test/ASW_label/batch': 0.8735139674932307,
#  'test/PCR_batch': 0.38274089462828587,
#  'test/graph_conn': 0.8982898335995337,
#  'test/avg_bio': 0.7698157793044077,
#  'test/batch_umap': <Figure size 320x320 with 1 Axes>,
#  'test/celltype_umap': <Figure size 320x320 with 1 Axes>,
#  'test/best_model_epoch': 25}

# %%
# save the best model
torch.save(best_model.state_dict(), save_dir / "best_model.pt")

# %%
gc.collect()
# Out:
# 35080

# %%
check_system_usage()
# Out:
# CPU usage: 4.9%
# Memory usage: 9.6%
# GPU 0: NVIDIA A10G, 0.0% load, 3887.0MB used of 23028.0MB
# Execution time: 0.024753332138061523 seconds
