# %% [markdown]
# # MEFISTO application to spatial transcriptomics

# %% [markdown]
# This notebook demonstrates how MEFISTO can be applied to spatial transcriptomics using its interface for muon.
#
# R vignette for this application [is available here](https://raw.githack.com/bioFAM/MEFISTO_tutorials/master/MEFISTO_ST.html#7_SessionInfo).

# %% [markdown]
# We use the `"Visium CytAssist Gene and Protein Expression Library of Human Tonsil with Add-on Antibodies, H&E, 6.5 mm (FFPE)"` dataset [provided by 10X Genomics](https://www.10xgenomics.com/datasets/visium-cytassist-gene-and-protein-expression-library-of-human-tonsil-with-add-on-antibodies-h-e-6-5-mm-ffpe-2-standard).
# The following files are used in this tutorial:
#
# - _Feature / cell matrix HDF5 (filtered)_ (`filtered_feature_bc_matrix.h5`),
# - _Spatial imaging data_ (`spatial.tar.gz`, has to be unarchived).

# %%
import psutil
import GPUtil

def get_system_metrics():
    # Get CPU usage
    cpu_usage = psutil.cpu_percent(interval=1)

    # Get total memory and memory used
    memory_info = psutil.virtual_memory()
    total_memory = memory_info.total / (1024 ** 3)  # Convert to GB
    memory_used = memory_info.used / (1024 ** 3)  # Convert to GB

    # Get GPU usage
    gpus = GPUtil.getGPUs()
    gpu_info = []
    for gpu in gpus:
        gpu_info.append({
            'id': gpu.id,
            'name': gpu.name,
            'load': gpu.load * 100,
            'memory_total': gpu.memoryTotal,
            'memory_used': gpu.memoryUsed,
            'temperature': gpu.temperature
        })

    return {
        'cpu_usage': cpu_usage,
        'total_memory': total_memory,
        'memory_used': memory_used,
        'gpu_info': gpu_info
    }

# Get the metrics
metrics = get_system_metrics()

# Print the metrics
print(f"CPU Usage: {metrics['cpu_usage']}%")
print(f"Total Memory: {metrics['total_memory']:.2f} GB")
print(f"Memory Used: {metrics['memory_used']:.2f} GB")

for gpu in metrics['gpu_info']:
    print(f"GPU ID: {gpu['id']}")
    print(f"GPU Name: {gpu['name']}")
    print(f"GPU Load: {gpu['load']:.2f}%")
    print(f"GPU Memory Total: {gpu['memory_total']} MB")
    print(f"GPU Memory Used: {gpu['memory_used']} MB")
    print(f"GPU Temperature: {gpu['temperature']} C")
# Out:
# CPU Usage: 0.0%
# Total Memory: 124.43 GB
# Memory Used: 2.28 GB
# GPU ID: 0
# GPU Name: NVIDIA A10G
# GPU Load: 6.00%
# GPU Memory Total: 23028.0 MB
# GPU Memory Used: 1.0 MB
# GPU Temperature: 23.0 C

# %%
import numpy as np
import pandas as pd
import scanpy as sc

import matplotlib.pyplot as plt
import seaborn as sns

import muon as mu

# Get the metrics
metrics = get_system_metrics()

# Print the metrics
print(f"CPU Usage: {metrics['cpu_usage']}%")
print(f"Total Memory: {metrics['total_memory']:.2f} GB")
print(f"Memory Used: {metrics['memory_used']:.2f} GB")

for gpu in metrics['gpu_info']:
    print(f"GPU ID: {gpu['id']}")
    print(f"GPU Name: {gpu['name']}")
    print(f"GPU Load: {gpu['load']:.2f}%")
    print(f"GPU Memory Total: {gpu['memory_total']} MB")
    print(f"GPU Memory Used: {gpu['memory_used']} MB")
    print(f"GPU Temperature: {gpu['temperature']} C")
# Out:
# CPU Usage: 0.1%
# Total Memory: 124.43 GB
# Memory Used: 2.26 GB
# GPU ID: 0
# GPU Name: NVIDIA A10G
# GPU Load: 4.00%
# GPU Memory Total: 23028.0 MB
# GPU Memory Used: 1.0 MB
# GPU Temperature: 24.0 C

# %% [markdown]
# ## Load data
#
# In this notebook, we put the files mentioned above into the `data/ST/` directory.

# %%
datadir = "data/Spatial_CITE_Seq"

adata = sc.read_visium(datadir)

# Get the metrics
metrics = get_system_metrics()

# Print the metrics
print(f"CPU Usage: {metrics['cpu_usage']}%")
print(f"Total Memory: {metrics['total_memory']:.2f} GB")
print(f"Memory Used: {metrics['memory_used']:.2f} GB")

for gpu in metrics['gpu_info']:
    print(f"GPU ID: {gpu['id']}")
    print(f"GPU Name: {gpu['name']}")
    print(f"GPU Load: {gpu['load']:.2f}%")
    print(f"GPU Memory Total: {gpu['memory_total']} MB")
    print(f"GPU Memory Used: {gpu['memory_used']} MB")
    print(f"GPU Temperature: {gpu['temperature']} C")
# Out:
# /home/ssh-user/miniconda/envs/scGPT_2/lib/python3.10/site-packages/anndata/_core/anndata.py:1756: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/ssh-user/miniconda/envs/scGPT_2/lib/python3.10/site-packages/anndata/_core/anndata.py:1756: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# CPU Usage: 0.0%
# Total Memory: 124.43 GB
# Memory Used: 2.60 GB
# GPU ID: 0
# GPU Name: NVIDIA A10G
# GPU Load: 4.00%
# GPU Memory Total: 23028.0 MB
# GPU Memory Used: 1.0 MB
# GPU Temperature: 24.0 C

# %% [markdown]
# ## QC and preprocessing

# %% [markdown]
# We will follow [scanpy's spatial tutorial](https://scanpy-tutorials.readthedocs.io/en/latest/spatial/basic-analysis.html) for the steps below.

# %%
adata.var["mt"] = adata.var_names.str.startswith("mt-")
sc.pp.calculate_qc_metrics(adata, qc_vars=["mt"], inplace=True)

fig, axs = plt.subplots(1, 4, figsize=(15, 4))
sns.distplot(adata.obs["total_counts"], kde=False, ax=axs[0])
sns.distplot(adata.obs["total_counts"][adata.obs["total_counts"] < 10000], kde=False, bins=40, ax=axs[1])
sns.distplot(adata.obs["n_genes_by_counts"], kde=False, bins=60, ax=axs[2])
sns.distplot(adata.obs["n_genes_by_counts"][adata.obs["n_genes_by_counts"] < 4000], kde=False, bins=60, ax=axs[3])

mu.pp.filter_obs(adata, 'total_counts', lambda x: x < 50000)
mu.pp.filter_obs(adata, 'pct_counts_mt', lambda x: x < 20)
mu.pp.filter_var(adata, 'n_cells_by_counts', lambda x: x > 10)

sc.pp.normalize_total(adata, inplace=True)
sc.pp.log1p(adata)
sc.pp.highly_variable_genes(adata, flavor="seurat", n_top_genes=2000)

sc.pl.spatial(adata, img_key="hires", color=["total_counts", "n_genes_by_counts"])

# Get the metrics
metrics = get_system_metrics()

# Print the metrics
print(f"CPU Usage: {metrics['cpu_usage']}%")
print(f"Total Memory: {metrics['total_memory']:.2f} GB")
print(f"Memory Used: {metrics['memory_used']:.2f} GB")

for gpu in metrics['gpu_info']:
    print(f"GPU ID: {gpu['id']}")
    print(f"GPU Name: {gpu['name']}")
    print(f"GPU Load: {gpu['load']:.2f}%")
    print(f"GPU Memory Total: {gpu['memory_total']} MB")
    print(f"GPU Memory Used: {gpu['memory_used']} MB")
    print(f"GPU Temperature: {gpu['temperature']} C")
# Out:
# /tmp/ipykernel_68959/639165815.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(adata.obs["total_counts"], kde=False, ax=axs[0])
# /tmp/ipykernel_68959/639165815.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(adata.obs["total_counts"][adata.obs["total_counts"] < 10000], kde=False, bins=40, ax=axs[1])
# /tmp/ipykernel_68959/639165815.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(adata.obs["n_genes_by_counts"], kde=False, bins=60, ax=axs[2])
# /tmp/ipykernel_68959/639165815.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(adata.obs["n_genes_by_counts"][adata.obs["n_genes_by_counts"] < 4000], kde=False, bins=60, ax=axs[3])
# CPU Usage: 0.0%
# Total Memory: 124.43 GB
# Memory Used: 2.68 GB
# GPU ID: 0
# GPU Name: NVIDIA A10G
# GPU Load: 4.00%
# GPU Memory Total: 23028.0 MB
# GPU Memory Used: 1.0 MB
# GPU Temperature: 24.0 C

# %% [markdown]
# We will now add spatial covariates to the `.obs` slot so that we can refer to them easily later:

# %%
adata.obs = pd.concat([adata.obs, 
                       pd.DataFrame(adata.obsm["spatial"], columns=["imagerow", "imagecol"], index=adata.obs_names),
                      ], axis=1)

# %% [markdown]
# ## Train a MEFISTO model

# %%
# We use 1000 inducing points to learn spatial covariance patterns
n_inducing = 1000

mu.tl.mofa(adata, n_factors=4, 
           smooth_covariate=["imagerow", "imagecol"],
           smooth_kwargs={
               "sparseGP": True, "frac_inducing": n_inducing/adata.n_obs, 
               "start_opt": 10, "opt_freq": 10,
           },
           outfile="models/mefisto_ST_GEX_2.hdf5",
           use_float32=True, seed=2021,
           quiet=False)

# Get the metrics
metrics = get_system_metrics()

# Print the metrics
print(f"CPU Usage: {metrics['cpu_usage']}%")
print(f"Total Memory: {metrics['total_memory']:.2f} GB")
print(f"Memory Used: {metrics['memory_used']:.2f} GB")

for gpu in metrics['gpu_info']:
    print(f"GPU ID: {gpu['id']}")
    print(f"GPU Name: {gpu['name']}")
    print(f"GPU Load: {gpu['load']:.2f}%")
    print(f"GPU Memory Total: {gpu['memory_total']} MB")
    print(f"GPU Memory Used: {gpu['memory_used']} MB")
    print(f"GPU Temperature: {gpu['temperature']} C")
# Out:
#         #########################################################
#         ###           __  __  ____  ______                    ###
#         ###          |  \/  |/ __ \|  ____/\    _             ###
#         ###          | \  / | |  | | |__ /  \ _| |_           ###
#         ###          | |\/| | |  | |  __/ /\ \_   _|          ###
#         ###          | |  | | |__| | | / ____ \|_|            ###
#         ###          |_|  |_|\____/|_|/_/    \_\              ###
#         ###                                                   ###
#         #########################################################
#
#
#
# use_float32 set to True: replacing float64 arrays by float32 arrays to speed up computations...
#
# Loaded view='rna' group='group1' with N=4734 samples and D=2000 features...
#
#
# Model options:
# - Automatic Relevance Determination prior on the factors: True
# - Automatic Relevance Determination prior on the weights: True
# - Spike-and-slab prior on the factors: False
# - Spike-and-slab prior on the weights: True
# Likelihoods:
# - View 0 (rna): gaussian
#
#
# Loaded 2 covariate(s) for each sample...
#
#
# Smooth covariate framework is activated. This is not compatible with ARD prior on factors. Setting ard_factors to False...
#
# ##
# ## sparseGP set to True: using sparse Gaussian Process to speed up the training procedure
# ##
#
#
# ######################################
# ## Training the model with seed 2021 ##
# ######################################
#
#
# ELBO before training: -36305445.50
#
# Iteration 1: time=2.24, ELBO=-3805143.34, deltaELBO=32500302.151 (89.51908373%), Factors=4
# Iteration 2: time=2.27, ELBO=-3530208.31, deltaELBO=274935.038 (0.75728320%), Factors=4
# Iteration 3: time=2.24, ELBO=-3521567.78, deltaELBO=8640.522 (0.02379952%), Factors=4
# Iteration 4: time=2.23, ELBO=-3516061.35, deltaELBO=5506.433 (0.01516696%), Factors=4
# Iteration 5: time=2.24, ELBO=-3511508.71, deltaELBO=4552.645 (0.01253984%), Factors=4
# Iteration 6: time=2.27, ELBO=-3507640.15, deltaELBO=3868.559 (0.01065559%), Factors=4
# Iteration 7: time=2.24, ELBO=-3504695.32, deltaELBO=2944.831 (0.00811127%), Factors=4
# Iteration 8: time=2.24, ELBO=-3502643.70, deltaELBO=2051.621 (0.00565100%), Factors=4
# Iteration 9: time=2.23, ELBO=-3501210.37, deltaELBO=1433.326 (0.00394796%), Factors=4
# Optimising sigma node...
# Iteration 10: time=63.65, ELBO=-3391890.99, deltaELBO=109319.386 (0.30111016%), Factors=4
# Iteration 11: time=5.54, ELBO=-4021081.31, deltaELBO=-629190.323 (1.73304669%), Factors=4
# Warning, lower bound is decreasing...
# Iteration 12: time=5.73, ELBO=-3966180.03, deltaELBO=54901.274 (0.15122049%), Factors=4
# Iteration 13: time=5.36, ELBO=-3943130.92, deltaELBO=23049.116 (0.06348666%), Factors=4
# Iteration 14: time=5.53, ELBO=-3928641.42, deltaELBO=14489.496 (0.03990998%), Factors=4
# Iteration 15: time=5.35, ELBO=-3918377.98, deltaELBO=10263.445 (0.02826971%), Factors=4
# Iteration 16: time=5.36, ELBO=-3910644.62, deltaELBO=7733.357 (0.02130082%), Factors=4
# Iteration 17: time=5.44, ELBO=-3904578.35, deltaELBO=6066.270 (0.01670898%), Factors=4
# Iteration 18: time=5.36, ELBO=-3899668.05, deltaELBO=4910.303 (0.01352498%), Factors=4
# Iteration 19: time=5.57, ELBO=-3895618.91, deltaELBO=4049.142 (0.01115299%), Factors=4
# Optimising sigma node...
# Iteration 20: time=64.95, ELBO=-3891313.17, deltaELBO=4305.740 (0.01185976%), Factors=4
# Iteration 21: time=5.35, ELBO=-4038966.88, deltaELBO=-147653.712 (0.40669853%), Factors=4
# Warning, lower bound is decreasing...
# Iteration 22: time=5.82, ELBO=-4033882.51, deltaELBO=5084.364 (0.01400441%), Factors=4
# Iteration 23: time=5.53, ELBO=-4030166.64, deltaELBO=3715.878 (0.01023504%), Factors=4
# Iteration 24: time=5.44, ELBO=-4026943.38, deltaELBO=3223.256 (0.00887816%), Factors=4
# Iteration 25: time=5.32, ELBO=-4024025.01, deltaELBO=2918.368 (0.00803838%), Factors=4
# Iteration 26: time=5.46, ELBO=-4021279.66, deltaELBO=2745.355 (0.00756183%), Factors=4
# Iteration 27: time=5.50, ELBO=-4018646.97, deltaELBO=2632.683 (0.00725148%), Factors=4
# Iteration 28: time=5.51, ELBO=-4016102.17, deltaELBO=2544.809 (0.00700944%), Factors=4
# Iteration 29: time=5.51, ELBO=-4013633.44, deltaELBO=2468.727 (0.00679988%), Factors=4
# Optimising sigma node...
# Iteration 30: time=71.23, ELBO=-4010853.32, deltaELBO=2780.117 (0.00765758%), Factors=4
# Iteration 31: time=5.36, ELBO=-3948657.01, deltaELBO=62196.310 (0.17131400%), Factors=4
# Iteration 32: time=5.39, ELBO=-3944247.65, deltaELBO=4409.360 (0.01214518%), Factors=4
# Iteration 33: time=5.77, ELBO=-3940578.14, deltaELBO=3669.511 (0.01010733%), Factors=4
# Iteration 34: time=5.58, ELBO=-3937204.19, deltaELBO=3373.948 (0.00929323%), Factors=4
# Iteration 35: time=5.48, ELBO=-3934187.92, deltaELBO=3016.276 (0.00830806%), Factors=4
# Iteration 36: time=5.35, ELBO=-3931459.83, deltaELBO=2728.087 (0.00751426%), Factors=4
# Iteration 37: time=5.61, ELBO=-3928991.72, deltaELBO=2468.108 (0.00679818%), Factors=4
# Iteration 38: time=5.39, ELBO=-3926816.45, deltaELBO=2175.269 (0.00599158%), Factors=4
# Iteration 39: time=5.53, ELBO=-3924896.99, deltaELBO=1919.463 (0.00528699%), Factors=4
# Optimising sigma node...
# Iteration 40: time=70.93, ELBO=-3922677.80, deltaELBO=2219.186 (0.00611254%), Factors=4
# Iteration 41: time=5.59, ELBO=-3947675.08, deltaELBO=-24997.276 (0.06885269%), Factors=4
# Warning, lower bound is decreasing...
# Iteration 42: time=5.35, ELBO=-3944888.04, deltaELBO=2787.036 (0.00767663%), Factors=4
# Iteration 43: time=5.61, ELBO=-3942065.49, deltaELBO=2822.549 (0.00777445%), Factors=4
# Iteration 44: time=5.41, ELBO=-3940156.33, deltaELBO=1909.158 (0.00525860%), Factors=4
# Iteration 45: time=5.46, ELBO=-3938726.98, deltaELBO=1429.351 (0.00393702%), Factors=4
# Iteration 46: time=5.30, ELBO=-3937512.59, deltaELBO=1214.397 (0.00334495%), Factors=4
# Iteration 47: time=5.56, ELBO=-3936469.99, deltaELBO=1042.597 (0.00287174%), Factors=4
# Iteration 48: time=5.17, ELBO=-3935527.46, deltaELBO=942.526 (0.00259610%), Factors=4
# Iteration 49: time=5.56, ELBO=-3934695.15, deltaELBO=832.314 (0.00229253%), Factors=4
# Optimising sigma node...
# Iteration 50: time=72.45, ELBO=-3930290.08, deltaELBO=4405.066 (0.01213335%), Factors=4
# Iteration 51: time=5.45, ELBO=-3926237.01, deltaELBO=4053.069 (0.01116380%), Factors=4
# Iteration 52: time=5.57, ELBO=-3925505.97, deltaELBO=731.045 (0.00201360%), Factors=4
# Iteration 53: time=5.43, ELBO=-3924954.87, deltaELBO=551.101 (0.00151796%), Factors=4
# Iteration 54: time=5.51, ELBO=-3924500.56, deltaELBO=454.308 (0.00125135%), Factors=4
# Iteration 55: time=5.39, ELBO=-3924136.70, deltaELBO=363.858 (0.00100221%), Factors=4
# Iteration 56: time=5.56, ELBO=-3923831.88, deltaELBO=304.817 (0.00083959%), Factors=4
# Iteration 57: time=5.32, ELBO=-3923587.65, deltaELBO=244.236 (0.00067272%), Factors=4
# Iteration 58: time=5.46, ELBO=-3923375.34, deltaELBO=212.307 (0.00058478%), Factors=4
# Iteration 59: time=5.39, ELBO=-3923211.40, deltaELBO=163.947 (0.00045158%), Factors=4
# Optimising sigma node...
# Iteration 60: time=72.95, ELBO=-3923022.83, deltaELBO=188.563 (0.00051938%), Factors=4
# Iteration 61: time=5.28, ELBO=-3929201.89, deltaELBO=-6179.062 (0.01701966%), Factors=4
# Warning, lower bound is decreasing...
# Iteration 62: time=5.48, ELBO=-3929079.63, deltaELBO=122.268 (0.00033677%), Factors=4
# Iteration 63: time=5.41, ELBO=-3928949.96, deltaELBO=129.670 (0.00035716%), Factors=4
#
# Converged!
#
#
#
# #######################
# ## Training finished ##
# #######################
#
#
# Saving model in models/mefisto_ST_GEX_2.hdf5...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 4
#       1 # We use 1000 inducing points to learn spatial covariance patterns
#       2 n_inducing = 1000
# ----> 4 mu.tl.mofa(adata, n_factors=4,
#       5            smooth_covariate=["imagerow", "imagecol"],
#       6            smooth_kwargs={
#       7                "sparseGP": True, "frac_inducing": n_inducing/adata.n_obs,
#       8                "start_opt": 10, "opt_freq": 10,
#       9            },
#      10            outfile="models/mefisto_ST_GEX_2.hdf5",
#      11            use_float32=True, seed=2021,
#      12            quiet=False)
#      14 # Get the metrics
#      15 metrics = get_system_metrics()
#
# File ~/miniconda/envs/scGPT_2/lib/python3.10/site-packages/muon/_core/tools.py:635, in mofa(data, groups_label, use_raw, use_layer, use_var, use_obs, likelihoods, n_factors, scale_views, scale_groups, center_groups, ard_weights, ard_factors, spikeslab_weights, spikeslab_factors, n_iterations, convergence_mode, use_float32, gpu_mode, gpu_device, svi_mode, svi_batch_size, svi_learning_rate, svi_forgetting_rate, svi_start_stochastic, smooth_covariate, smooth_warping, smooth_kwargs, save_parameters, save_data, save_metadata, seed, outfile, expectations, save_interrupted, verbose, quiet, copy)
#     633     w = np.concatenate([expectations_w[m][:, :] for m in data.mod], axis=1).T
#     634 else:
# --> 635     w = expectations_w["data"][:, :].T
#     637 if use_var:
#     638     # Set the weights of features that were not used to zero
#     639     data.varm["LFs"] = np.zeros(shape=(data.n_vars, w.shape[1]))
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File ~/miniconda/envs/scGPT_2/lib/python3.10/site-packages/h5py/_hl/group.py:357, in Group.__getitem__(self, name)
#     355         raise ValueError("Invalid HDF5 object reference")
#     356 elif isinstance(name, (bytes, str)):
# --> 357     oid = h5o.open(self.id, self._e(name), lapl=self._lapl)
#     358 else:
#     359     raise TypeError("Accessing a group is done with bytes or str, "
#     360                     "not {}".format(type(name)))
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5o.pyx:257, in h5py.h5o.open()
#
# KeyError: "Unable to synchronously open object (object 'data' doesn't exist)"

# %%
metrics = get_system_metrics()
# Print the metrics
print(f"CPU Usage: {metrics['cpu_usage']}%")
print(f"Total Memory: {metrics['total_memory']:.2f} GB")
print(f"Memory Used: {metrics['memory_used']:.2f} GB")

for gpu in metrics['gpu_info']:
    print(f"GPU ID: {gpu['id']}")
    print(f"GPU Name: {gpu['name']}")
    print(f"GPU Load: {gpu['load']:.2f}%")
    print(f"GPU Memory Total: {gpu['memory_total']} MB")
    print(f"GPU Memory Used: {gpu['memory_used']} MB")
    print(f"GPU Temperature: {gpu['temperature']} C")
# Out:
# CPU Usage: 0.1%
# Total Memory: 124.43 GB
# Memory Used: 4.42 GB
# GPU ID: 0
# GPU Name: NVIDIA A10G
# GPU Load: 4.00%
# GPU Memory Total: 23028.0 MB
# GPU Memory Used: 1.0 MB
# GPU Temperature: 24.0 C

# %% [markdown]
# ## Downstream analyses

# %% [markdown]
# For some of the functionality below we will also use [mofax](https://github.com/bioFAM/mofax).

# %%
import mofax
m = mofax.mofa_model("models/mefisto_ST_GEX.hdf5")

# %% [markdown]
# ### Factors correlation

# %% [markdown]
# First, we can take a look whether our factor are uncorrelated.

# %%
mofax.plot_factors_correlation(m);

# %% [markdown]
# ### Spatial factors

# %% [markdown]
# We will then have a look at the spatial patterns that are captured by each factor.

# %%
for i in range(4):
    adata.obs[f"Factor{i+1}"] = adata.obsm["X_mofa"][:,i]

# %%
sc.pl.spatial(adata, img_key="hires", color=[f"Factor{i+1}" for i in range(4)])

# %% [markdown]
# ### Smoothness of factors

# %% [markdown]
# All of this factors seem to capture spatial patterns of variation that seems to vary smoothly along space to some extent. We can take a look at the smoothness score inferred by the model.

# %%
mofax.plot_smoothness(m)
# Out:
# <Axes: xlabel='Smoothness', ylabel='Factor'>

# %% [markdown]
# ### Weights

# %% [markdown]
# We will take `Factor4` as an example to show the spatial expression pattern for genes that have the highest weights for that factor.

# %%
top_features_f4 = m.get_top_features(factors="Factor4", n_features=3)
top_features_f4
# Out:
# array(['SPRR1B', 'SPRR3', 'PI3'], dtype=object)

# %%
sc.pl.spatial(adata, img_key="hires", color=top_features_f4)
